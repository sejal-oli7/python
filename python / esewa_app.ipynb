# %% [markdown]
# <a href="https://colab.research.google.com/github/sejal-oli7/python/blob/main/python%20/%20esewa_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
class DigitalWallet:
  def __init__(self, user_name, initial_balance=0):
    self.owner = user_name
    self.wallet_id = f"NP-{random.randint(10000,99999)}"
    self._balance = initial_balance #Protected attributes
    self.history = [] #

  def check_balance(self):
    return self._balance
