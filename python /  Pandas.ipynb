# %% [markdown]
# <a href="https://colab.research.google.com/github/sejal-oli7/python/blob/main/python%20/%20%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Exercise 1
# We need pandas to get to know about the pandas.

# %%
#@ Importing necessary
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv("food.tsv", sep="\t")

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3308/3624354784.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("food.tsv", sep="\t")
#       4
#       5 print(df.head())
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'food.tsv'

# %% [markdown]
# ## Pandas EXercise 2

# %%
#@ IMporting Library
import pandas as pd
import numpy as np

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"

df = pd.read_csv(
    url,
    sep="|",
    index_col="user_id"
)

print(df.head())

# %%
df.head(25)

# %%
df.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3308/4126922567.py in <cell line: 0>()
# ----> 1 df.tail(10)
#
# NameError: name 'df' is not defined

# %%
#@ how many numbers of data we have?
df.shape [0]

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3308/3289350417.py in <cell line: 0>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.dtypes

# %%
#@ only print occupation columns
df.occupation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3308/3748867683.py in <cell line: 0>()
#       1 #@ only print occupation columns
# ----> 2 df.occupation
#
# NameError: name 'df' is not defined

# %%
df['occupation']

# %%
#@ how many different occupations are in the datasets
df.occupation.nunique()

# %%
df.occupation.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3308/2027501711.py in <cell line: 0>()
# ----> 1 df.occupation.value_counts()
#
# NameError: name 'df' is not defined

# %%
df.occupation.value_counts().count()

# %%
#@ Lets describe your dataset by summarizing it
df.describe()

# %% [markdown]
# Only numeric columns are return , if you only describe the dataframe

# %%
#@ If we need all then
df.describe(include="all")

# %%
df.occupation.describe()

# %%
#@ what is the mean age of users?
round(df.age.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3308/374956595.py in <cell line: 0>()
#       1 #@ what is the mean age of users?
# ----> 2 round(df.age.mean())
#
# NameError: name 'df' is not defined

# %%
#@ the least occurance of age
df.age.value_counts().tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3308/2860469237.py in <cell line: 0>()
#       1 #@ the least occurance of age
# ----> 2 df.age.value_counts().tail()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Pandas Exercise3

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df = pd.read_csv(url, sep='\t')

# %%
#@ inspecting the dataset
df.head(20)

# %%
#@ number of observation
df.shape[0]

# %%
df.info()

# %%
df.shape[1]

# %%
df.columns

# %%
#@ which was the most order items
#group by
i = df.groupby('item_name')
i
i= i.sum()
i = i.sort_values(['quantity'], ascending=False)
i.head(1)

# %%
#@ what was the most order item in the choice description column
df.groupby('choice_description').sum().sort_values(['quantity'], ascending=False).head(1)

# %%
import pandas as pd
data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "class": ["V", "V", "VI", "VI", "V", "VI"],
    "name": [
        "Alberto Franco",
        "Gino Mcneill",
        "Ryan Parkes",
        "Eesha Hinton",
        "Gino Mcneill",
        "David Parkes"
    ],
    "date_Of_Birth": [
        "15/05/2002",
        "17/05/2002",
        "16/02/1999",
        "25/09/1998",
        "11/05/2002",
        "15/09/1997"
    ],
    "age": [12, 12, 13, 13, 14, 12],
    "height": [173, 192, 186, 167, 151, None],
    "weight": [35, 32, 33, 30, 31, None],
    "address": [
        "street1",
        "street2",
        "street3",
        "street1",
        "street2",
        None
    ]
}

df = pd.DataFrame(data)

# Group by school
grouped = df.groupby("school")

# Check the type
print(type(grouped))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
import pandas as pd

data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "age": [12, 12, 13, 13, 14, 12]
}

df = pd.DataFrame(data)

result = df.groupby("school")["age"].agg(
    ["mean", "min", "max"]
)

print(result)
# Out:
#         mean  min  max
# school
# s001    12.5   12   13
# s002    13.0   12   14
# s003    13.0   13   13
# s004    12.0   12   12

# %%
import pandas as pd

data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "class": ["V", "V", "VI", "VI", "V", "VI"],
    "name": [
        "Alberto Franco",
        "Gino Mcneill",
        "Ryan Parkes",
        "Eesha Hinton",
        "Gino Mcneill",
        "David Parkes"
    ],
    "age": [12, 12, 13, 13, 14, 12]
}

df = pd.DataFrame(data)

grouped = df.groupby(["school", "class"])

for name, group in grouped:
    print("Group:", name)
    print(group)
    print()
# Out:
# Group: ('s001', 'V')
#   school class            name  age
# 0   s001     V  Alberto Franco   12
#
# Group: ('s001', 'VI')
#   school class          name  age
# 3   s001    VI  Eesha Hinton   13
#
# Group: ('s002', 'V')
#   school class          name  age
# 1   s002     V  Gino Mcneill   12
# 4   s002     V  Gino Mcneill   14
#
# Group: ('s003', 'VI')
#   school class         name  age
# 2   s003    VI  Ryan Parkes   13
#
# Group: ('s004', 'VI')
#   school class          name  age
# 5   s004    VI  David Parkes   12

# %%
import pandas as pd

data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "name": [
        "Alberto Franco",
        "Gino Mcneill",
        "Ryan Parkes",
        "Eesha Hinton",
        "Gino Mcneill",
        "David Parkes"
    ]
}

df = pd.DataFrame(data)

grouped = df.groupby("school")

groups = list(grouped)

print(groups)
# Out:
# [('s001',   school            name
# 0   s001  Alberto Franco
# 3   s001    Eesha Hinton), ('s002',   school          name
# 1   s002  Gino Mcneill
# 4   s002  Gino Mcneill), ('s003',   school         name
# 2   s003  Ryan Parkes), ('s004',   school          name
# 5   s004  David Parkes)]
