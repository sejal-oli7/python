# %% [markdown]
# <a href="https://colab.research.google.com/github/sejal-oli7/python/blob/main/python%20/%20%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Exercise 1
# We need pandas to get to know about the pandas.

# %%
#@ Importing necessary
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv("food.tsv", sep="\t")

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_643/3624354784.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("food.tsv", sep="\t")
#       4
#       5 print(df.head())
#
# ...

# %% [markdown]
# ## Pandas EXercise 2

# %%
#@ IMporting Library
import pandas as pd
import numpy as np

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"

df = pd.read_csv(
    url,
    sep="|",
    index_col="user_id"
)

print(df.head())

# %%
df.head(25)

# %%
df.tail(10)

# %%
#@ how many numbers of data we have?
df.shape [0]

# %%
df.columns

# %%
df.dtypes

# %%
#@ only print occupation columns
df.occupation

# %%
df['occupation']

# %%
#@ how many different occupations are in the datasets
df.occupation.nunique()

# %%
df.occupation.value_counts()

# %%
df.occupation.value_counts().count()

# %%
#@ Lets describe your dataset by summarizing it
df.describe()

# %% [markdown]
# Only numeric columns are return , if you only describe the dataframe

# %%
#@ If we need all then
df.describe(include="all")

# %%
df.occupation.describe()

# %%
#@ what is the mean age of users?
round(df.age.mean())

# %%
#@ the least occurance of age
df.age.value_counts().tail()

# %% [markdown]
# ## Pandas Exercise3

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df = pd.read_csv(url, sep='\t')

# %%
#@ inspecting the dataset
df.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
#@ number of observation
df.shape[0]
# Out:
# 4622

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.shape[1]
# Out:
# 5

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#@ which was the most order items
#group by
i = df.groupby('item_name')
i
i= i.sum()
i = i.sort_values(['quantity'], ascending=False)
i.head(1)
# Out:
#               order_id  quantity  \
# item_name
# Chicken Bowl    713926       761
#
#                                              choice_description  \
# item_name
# Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#
#                                                      item_price
# item_name
# Chicken Bowl  $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 ...

# %%
#@ what was the most order item in the choice description column
df.groupby('choice_description').sum().sort_values(['quantity'], ascending=False).head(1)
# Out:
#                     order_id  quantity  \
# choice_description
# [Diet Coke]           123455       159
#
#                                                             item_name  \
# choice_description
# [Diet Coke]         Canned SodaCanned SodaCanned Soda6 Pack Soft D...
#
#                                                            item_price
# choice_description
# [Diet Coke]         $2.18 $1.09 $1.09 $6.49 $2.18 $1.25 $1.09 $6.4...

# %%
import pandas as pd
data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "class": ["V", "V", "VI", "VI", "V", "VI"],
    "name": [
        "Alberto Franco",
        "Gino Mcneill",
        "Ryan Parkes",
        "Eesha Hinton",
        "Gino Mcneill",
        "David Parkes"
    ],
    "date_Of_Birth": [
        "15/05/2002",
        "17/05/2002",
        "16/02/1999",
        "25/09/1998",
        "11/05/2002",
        "15/09/1997"
    ],
    "age": [12, 12, 13, 13, 14, 12],
    "height": [173, 192, 186, 167, 151, None],
    "weight": [35, 32, 33, 30, 31, None],
    "address": [
        "street1",
        "street2",
        "street3",
        "street1",
        "street2",
        None
    ]
}

df = pd.DataFrame(data)

# Group by school
grouped = df.groupby("school")

# Check the type
print(type(grouped))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
import pandas as pd

data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "age": [12, 12, 13, 13, 14, 12]
}

df = pd.DataFrame(data)

result = df.groupby("school")["age"].agg(
    ["mean", "min", "max"]
)

print(result)
# Out:
#         mean  min  max
# school
# s001    12.5   12   13
# s002    13.0   12   14
# s003    13.0   13   13
# s004    12.0   12   12

# %%
import pandas as pd

data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "class": ["V", "V", "VI", "VI", "V", "VI"],
    "name": [
        "Alberto Franco",
        "Gino Mcneill",
        "Ryan Parkes",
        "Eesha Hinton",
        "Gino Mcneill",
        "David Parkes"
    ],
    "age": [12, 12, 13, 13, 14, 12]
}

df = pd.DataFrame(data)

grouped = df.groupby(["school", "class"])

for name, group in grouped:
    print("Group:", name)
    print(group)
    print()
# Out:
# Group: ('s001', 'V')
#   school class            name  age
# 0   s001     V  Alberto Franco   12
#
# Group: ('s001', 'VI')
#   school class          name  age
# 3   s001    VI  Eesha Hinton   13
#
# Group: ('s002', 'V')
#   school class          name  age
# 1   s002     V  Gino Mcneill   12
# 4   s002     V  Gino Mcneill   14
#
# Group: ('s003', 'VI')
#   school class         name  age
# 2   s003    VI  Ryan Parkes   13
#
# Group: ('s004', 'VI')
#   school class          name  age
# 5   s004    VI  David Parkes   12

# %%
import pandas as pd

data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "name": [
        "Alberto Franco",
        "Gino Mcneill",
        "Ryan Parkes",
        "Eesha Hinton",
        "Gino Mcneill",
        "David Parkes"
    ]
}

df = pd.DataFrame(data)

grouped = df.groupby("school")

groups = list(grouped)

print(groups)
# Out:
# [('s001',   school            name
# 0   s001  Alberto Franco
# 3   s001    Eesha Hinton), ('s002',   school          name
# 1   s002  Gino Mcneill
# 4   s002  Gino Mcneill), ('s003',   school         name
# 2   s003  Ryan Parkes), ('s004',   school          name
# 5   s004  David Parkes)]

# %%
import pandas as pd

data = {
    "school": ["s001", "s002", "s003", "s001", "s002", "s004"],
    "class": ["V", "V", "VI", "VI", "V", "VI"]
}

df = pd.DataFrame(data)

result = df.groupby("school").size()

print(result)
# Out:
# school
# s001    2
# s002    2
# s003    1
# s004    1
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("dataset.csv")

df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5  2[4]           NaN  $345,675,146                     $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   school  6 non-null      object
#  1   class   6 non-null      object
# dtypes: object(2)
# memory usage: 228.0+ bytes

# %%
df.columns
# Out:
# Index(['school', 'class'], dtype='object')
